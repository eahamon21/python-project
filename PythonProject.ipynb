# %%
import seaborn as sns

# %%
mpg = sns.load_dataset("mpg")
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
Create a visual showing the relationship between horsepower and fuel economy.

# %%
# The more MPG a vehicle has, the less horsepower it possesses. Vice versa for less MPG=more horsepower.
sns.relplot(
    data=mpg,
    x="mpg", y="horsepower"
)

# %%
Create a table summarizing fuel economy by country of origin.

# %%
import seaborn as sns

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.lineplot(data=mpg, x='origin', y='mpg')
# Out:
# C:\Users\jeffy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jeffy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
mpg = ({'Origin': ['USA', 'Japan', 'Europe'],
                   'mpg': [20., 22., 24., 26., 28., 30., 32.]} )

# %%
Create a visual showing how fuel economy has changed over time.

# %%
# As the model_year of the vehicles get higher, you can see that the mpg also gets higher based on the trend line.
sns.relplot(data=mpg, x="model_year", y="mpg", kind="line")
# Out:
# C:\Users\jeffy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jeffy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
Create two other visuals or tables related to fuel economy.

# %%
#Visual 1= A vehcile with a weight around 2000-2400 is the optimal weight for best MPG. 
            # The heavier the vehicle gets, the less MPG it has.
plt.figure(figsize=(10, 6))
sns.histplot(data=mpg, x='weight')
plt.title('How Weight Affects MPG')
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.grid(False)
plt.show()
# Out:
# C:\Users\jeffy\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Visual 2= The average cylinder of 5 looks to have the highest mpg, so having more than 5 means lower mpg.
sns.catplot(data=mpg, x="cylinders", y="mpg", kind="bar")
